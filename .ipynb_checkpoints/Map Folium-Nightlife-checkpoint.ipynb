# %% [markdown]
# # Plot the graphs

# %%
#define the Headers 
import folium
import pandas as pd
import numpy as np
import vincent

# %%
nightlife_df = pd.read_csv('data_sources/nightlife_data_combined_with_cords.csv')

nightlife_df = nightlife_df.drop(['Unnamed: 0'], axis=1)

nightlife_df.head()
# Out:
#    Zip Code  Restaurant Count  Restaurant Rating  Bar Count  Bar Rating  \
# 0     73301               3.0           4.500000        0.0    0.000000
# 1     78617               1.0           4.000000        2.0    3.000000
# 2     78646               2.0           4.500000        0.0    0.000000
# 3     78660               4.0           3.125000        2.0    3.000000
# 4     78701             201.0           4.186567      194.0    4.265464
#
#    Club Count  Club Rating   Latitude  Longitude  Bar/Restaurant Count  \
# 0         0.0     0.000000  30.220098 -97.749046                   3.0
# 1         0.0     0.000000  30.201016 -97.665245                   3.0
# 2         0.0     0.000000  30.273205 -97.800709                   2.0
# 3         0.0     0.000000  30.453564 -97.666576                   6.0
# 4       223.0     3.376682  30.267238 -97.741325                 618.0
#
#    Bar/Restaurant Rating  Total Nightlife Count  Combined Rating
# ...

# %% [markdown]
# ## get shools has more then 7 rating

# %%
#school_8 = schools_df[schools_df["gsRating"]>7 ].dropna(how='any')
#school_8.head()
# Out:
#       gsId                             name    city state  \
# 13  5869.0  Anderson Mill Elementary School  Austin    TX
# 34  7781.0    Bannockburn Christian Academy  Austin    TX
# 36   523.0     Barrington Elementary School  Austin    TX
# 38   524.0   Barton Hills Elementary School  Austin    TX
# 39  2035.0           Baty Elementary School  Austin    TX
#
#                                            address        lat        lon  \
# 13   10610 Salt Mill Hollow, \r\nAustin, TX  78750  30.452835 -97.806854
# 34           7100 Brodie Ln, \r\nAustin, TX  78745  30.212337 -97.832400
# 36         400 Cooper Drive, \r\nAustin, TX  78753  30.360529 -97.696070
# 38  2108 Barton Hills Drive, \r\nAustin, TX  78704  30.254395 -97.783356
# 39          2101 Faro Drive, \r\nAustin, TX  78741  30.227068 -97.712814
#
#        type  gsRating  Zipcode
# 13   public       8.0  78750.0
# 34  private       8.0  78745.0
# 36   public       9.0  78753.0
# 38   public      10.0  78704.0
# ...

# %% [markdown]
# ## Plot the map

# %%
def Plotmap(mp, df):
    #print(df.head())
    #set up the map for Austin for now Austin location (30.25, -97.75)
    m = folium.Map(location=[30.35, -97.75], zoom_start=11)
    
    # Add marker one by one on the map
    for i, row in df.iterrows():
        #print(f"index {i}")
        folium.Circle(
            location=[df.loc[i]['Latitude'], df.loc[i]['Longitude']],
            popup=df.loc[i]['Zip Code'].split()[0],
            radius=df.loc[i]['Combined Rating']*50,
            color='crimson',
            fill=True,
            fill_color='crimson'
        ).add_to(mp)    
        
    return mp 
#Plotmap(nightlife_df)

# %% [markdown]
# ## Get the choice from the user

# %%
def getuserinput():
    choice = 'Nightlife'
    return choice

# %%
#Print the map according to choice

mp = folium.Map(location=[30.35, -97.75], zoom_start=11)
choice = 'Nightlife'
if getuserinput() == 'Nightlife':
    Plotmap(mp, nightlife_df)
else:
    print("Nightlife")
mp
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-d7e33065cce8> in <module>()
#       4 choice = 'Nightlife'
#       5 if getuserinput() == 'Nightlife':
# ----> 6     Plotmap(mp, nightlife_df)
#       7 else:
#       8     print("Nightlife")
#
# <ipython-input-9-86533995c660> in Plotmap(mp, df)
#       7     for i, row in df.iterrows():
#       8         #print(f"index {i}")
# ----> 9         folium.circle(
#      10             location=[df.loc[i]['Latitude'], df.loc[i]['Longitude']],
#      11             popup=df.loc[i]['Zip Code'].split()[0],
#
# AttributeError: module 'folium' has no attribute 'circle'

# %% [markdown]
# cat_4 = ['Metric_' + str(x) for x in range(0, 10, 1)]
# index_4 = ['Data 1', 'Data 2', 'Data 3', 'Data 4']
# data_3 = {}
# for cat in cat_4:
#     data_3[cat] = [random.randint(10, 100) for x in index_4]
# df_2 = pd.DataFrame(data_3, index=index_4)

# %%
index_2 = ['Restaurants', 'Bars', 'Clubs']

for i, row in nightlife_df.iterrows():
    data_3 = {}
    data_3['Rating'] = [nightlife_df.loc[i]['Restaurant Rating']*2, nightlife_df.loc[i]['Bar Rating']* 2, nightlife_df.loc[i]['Club Rating']* 2]
    
    df_2 = pd.DataFrame(data_3, index=index_2)

    bar_chart = vincent.GroupedBar(df_2, width=100, height=100 )
    bar_chart.colors(range_= [ '#8856a7'])
    #bar_chart.legend(title='Categories')

    
    t = nightlife_df.loc[i]["Zipcode"]
    bar_chart.axis_titles(x=t, y='Ratings')

    popup = folium.Popup()
    folium.Vega(bar_chart, height=150, width=200).add_to(popup)
    
    folium.Marker([nighlife_df.loc[i]['Latitude'], nightlife_df.loc[i]['Longitude']], popup=popup).add_to(mp)
    
mp
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
